# %%
# === Task 3: Retrieval-Augmented Generation (RAG) ===

import faiss
import json
from sentence_transformers import SentenceTransformer
from transformers import pipeline

# === Load FAISS index and metadata ===
index = faiss.read_index("vector_store/faiss_index.bin")
with open("vector_store/metadata.json", "r", encoding="utf-8") as f:
    metadata = json.load(f)

# === Load the same embedding model used in Task 2 ===
embedder = SentenceTransformer("paraphrase-MiniLM-L3-v2")

# === Load a small LLM for generation (can be swapped later) ===
generator = pipeline("text-generation", model="gpt2", max_length=512)

# === RAG Retriever Function ===
def retrieve_top_k_chunks(query: str, k: int = 5):
    query_embedding = embedder.encode([query], convert_to_numpy=True).astype("float32")
    distances, indices = index.search(query_embedding, k)
    return [metadata[i]["chunk"] for i in indices[0]]

# === Prompt Template Builder ===
def build_prompt(context_chunks, question):
    context = "\n\n".join(context_chunks)
    prompt = f"""
You are a financial analyst assistant for CrediTrust. Your task is to answer questions about customer complaints.

Use the following retrieved complaint excerpts to formulate your answer. If the context doesn't contain the answer, state that you don't have enough information.

Context:
{context}

Question: {question}

Answer:"""
    return prompt.strip()

# === RAG Generator Pipeline ===
def answer_question_rag(query, k=5):
    retrieved_chunks = retrieve_top_k_chunks(query, k)
    prompt = build_prompt(retrieved_chunks, query)
    response = generator(prompt, max_new_tokens=200, do_sample=True, temperature=0.7)[0]["generated_text"]

    # Extract answer after "Answer:" if present
    answer_start = response.find("Answer:")
    answer = response[answer_start + len("Answer:"):].strip() if answer_start != -1 else response.strip()

    return {
        "question": query,
        "answer": answer,
        "retrieved_chunks": retrieved_chunks
    }
# Out:
# c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\pc\.cache\huggingface\hub\models--gpt2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Device set to use cpu

# %%
import textwrap

# === Evaluation Questions ===
evaluation_questions = [
    "Why are customers unhappy with the Buy Now, Pay Later (BNPL) service?",
    "What are the most common reasons for credit card account closures?",
    "How often do users complain about overdraft or late payment fees on savings accounts?",
    "Are there any fraud-related complaints in personal loan applications?",
    "Can I dispute a late payment fee?"
]

# === Run RAG pipeline and collect answers ===
results = []
for q in evaluation_questions:
    rag_result = answer_question_rag(q)
    results.append({
        "question": q,
        "answer": rag_result["answer"],
        "sources": " | ".join(chunk.replace("\n", " ")[:300] for chunk in rag_result["retrieved_chunks"][:2]),  # Shortened and cleaned
        "quality": "",
        "comments": ""
    })

# === Print nicely ===
for i, r in enumerate(results, 1):
    print(f"\n=== Question {i} ===")
    print(f"Q: {r['question']}")
    print("Answer:")
    print(textwrap.fill(r['answer'], width=100))
    print("\nRetrieved Sources:")
    print(textwrap.fill(r['sources'], width=100))
    print(f"\nQuality Score (1-5): {r['quality']}")
    print(f"Comments: {r['comments']}")
    print("=" * 120)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# === Question 1 ===
# Q: Why are customers unhappy with the Buy Now, Pay Later (BNPL) service?
# Answer:
# I understand that this service is not a good option for customers and it is not an option for the
# merchants. My answer is that the offer to use the service is not a good option for the merchants and
# the merchants have to pay for it. The only way they can get it is to buy it from the merchants and
# then they can give it to the customers who are paying the bill.  I understand that this service is
# not a good option for all customers but for the merchants are the only ones who can afford to pay
# for it. When you go into a store and are asked to provide the service and you provide the same
# service to all of your customers it is not a good service for them but it is bad for the customers.
# I understand that we are in a market where there are a lot of shopping malls and you can't just go
# out there and buy the cheapest goods and services and people will not even bother to use it  Why
# would these merchants be
#
# Retrieved Sources:
# until xx xx i actually like their stores and i m not sure why they would treat a loyal customer this
# way i think it is extremely poor business aside from that it has affected my credit score in a
# negative manner with no notice or opportunity to correct the matter | for why this happened they
# also claimed the vendor tried multiple times to put the card through this is untrue very
# embarrassing and worrisome to me as i wondered if something was wrong credit card companies and
# banks have enormous power and consumers are left with situations like this they should
#
# Quality Score (1-5):
# Comments:
# ========================================================================================================================
#
# === Question 2 ===
# Q: What are the most common reasons for credit card account closures?
# Answer:
# it is not a good idea for you to be a financial manager for a small business you have lost your job
# due to a lack of credit card processing and it is not a good idea to pay off your credit card
# balance at the last minute.  if you are not sure if you are in a bad situation, you can ask us a
# number of questions that we can help you.
#
# Retrieved Sources:
# hello please provide me a detailed explanation why all my credit card accounts have been closed and
# the remaining balances if any on the accts | their wrongs i still have to pay these credit cards my
# accounts should not have been closed as they were when i called on xx xx xxxx i was not even told i
# was in danger of account closure or losing my credit protection benefits this company is all wrong
# and has to be addressed they are setting
#
# Quality Score (1-5):
# Comments:
# ========================================================================================================================
#
# === Question 3 ===
# Q: How often do users complain about overdraft or late payment fees on savings accounts?
# Answer:
# a m t bank is wrong in offering any kind of overdraft penalty if your account is held for less than
# one year and your bank is forced to close the account at least once for the first year  a m t bank
# is wrong in claiming that once the payment came out at midnight i am automatically due an overdraft
# fee if the funds are not in the account this is false and contrary to their policy which allows for
# overdrawn accounts to be brought back to a positive balance on the day of the account you are making
# a statement about your account being closed  context:  A fee is charged if the amount you pay is not
# in your account at the time of your account closing or the amount of the overdraft fee for the month
# you have paid  context:  Your bank is using the wrong fee for a overdraft fee if their account is
# closed  context:  The wrong fee is charged for a debit card. That is, you are charged
#
# Retrieved Sources:
# a fee m t bank is erroneously claiming that once the payment came out at midnight i am automatically
# due an overdraft fee if the funds are not in the account this is false and contrary to their policy
# which allows for overdrawn accounts to be brought back to a positive balance on the day of the | i
# was charged overdraft fees because a payment came out of the wrong account the bank was completely
# unwilling to help and waive the fees considering the fact that i got money into the account the next
# day and that ive had an account in good standing for over a decade they should be able to help
#
# Quality Score (1-5):
# Comments:
# ========================================================================================================================
#
# === Question 4 ===
# Q: Are there any fraud-related complaints in personal loan applications?
# Answer:
# As a financial analyst, a financial analyst assistant for CrediTrust you will be responsible to
# follow all relevant federal and state guidelines regarding personal loan applications, including the
# following guidelines:  If you are requesting a loan, you may use a credit report to assist you in
# obtaining a loan  you may report to us at CrediTrust a loan receipt and payment information  you may
# request a loan from us to verify that you have the correct amount of money  You may request or
# provide payment information from us at the CrediTrust office and we will provide you with an invoice
# for the loan and a copy of the payment  You may report to us the amount of money you have borrowed
# and the amount of money you have already borrowed  if you have the right to file a complaint but are
# not sure about your eligibility to file a complaint we will not collect your complaint and will not
# charge you any fees for filing.  If you are seeking to
#
# Retrieved Sources:
# i am writing to file a formal complaint against self lender regarding their failure to adequately
# investigate and manage issues related to my secured loan account their actions have led to
# inaccurate reporting on my credit history which i believe to be the direct result of their improper
# handling of | due to their ongoing mishandling of a recent fraud incident on my account i reported a
# fraudulent transaction and requested provisional credit but was only offered a reimbursement this
# was issued without any understanding or acknowledgement of the financial hardship system failures
# and emotional
#
# Quality Score (1-5):
# Comments:
# ========================================================================================================================
#
# === Question 5 ===
# Q: Can I dispute a late payment fee?
# Answer:
# If the client is not aware of the late fee in the receipt, they can ask for the correct form of
# payment. If the client doesn't know the correct form of payment, they can ask for a refund and they
# can then refund any late fee.  In order to avoid a legal problem, you should have some way of
# getting in touch with a legal representative, or in some cases, a lawyer.  There are a number of
# good legal services available online, including:  Online banking services  CrediTrust is a legal
# company that provides legal services to clients.  If you are looking for a legal services or legal
# support service in your area, you should look for a law firm that specializes in the legal aspects
# of your case.  Lawyers are not necessarily professionals, and lawyers are not always professional
# and they may not be able to provide you with the legal services you need.  You can find more
# information at the following links:
#
# Retrieved Sources:
# every month my payment is one amount xxxx payment when im late they add a xxxx dollar late fee every
# month they say its cleared for the next month there another late fee i pay the late fee separate but
# because i have to wait to pay the extra fee they charged then they charge me another late fee this |
# have been a problem i dont think i should have to pay late fees because they didnt ask for the
# correct form of payment and did not communicate with me that the payments were reversed to give me a
# chance to fix it before incurring more penalties
#
# Quality Score (1-5):
# Comments:
# ========================================================================================================================

# %%
def answer_question_rag(query, k=5):
    ...
    return {
        "question": query,
        "answer": answer,
        "retrieved_chunks": retrieved_chunks
    }

def gradio_interface(query):
    result = answer_question_rag(query)
    answer = result["answer"]
    sources = "\n\n---\n\n".join(result["retrieved_chunks"][:2])  # show top 2 sources
    return answer, sources

# %%
import gradio as gr

interface = gr.Interface(
    fn=gradio_interface,
    inputs=gr.Textbox(lines=2, placeholder="Enter your question here...", label="User Question"),
    outputs=[
        gr.Textbox(label="Answer"),
        gr.Textbox(label="Top Retrieved Chunks")
    ],
    title="CrediTrust Complaint Assistant (RAG)",
    description="Ask a question about financial complaints. Answer is generated using retrieved complaint chunks.",
)

interface.launch(share=True)  # `share=True` gives public URL
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://a85b3ca897e83ee921.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://a85b3ca897e83ee921.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\gradio\queueing.py", line 626, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\gradio\route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\gradio\blocks.py", line 2220, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\gradio\blocks.py", line 1731, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 2470, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 967, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\gradio\utils.py", line 940, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\pc\AppData\Local\Temp\ipykernel_3408\1497047482.py", line 10, in gradio_interface
#     result = answer_question_rag(query)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\pc\AppData\Local\Temp\ipykernel_3408\1497047482.py", line 5, in answer_question_rag
#     "answer": answer,
#               ^^^^^^
# NameError: name 'answer' is not defined
# Traceback (most recent call last):
#   File "c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\gradio\queueing.py", line 626, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\gradio\route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\gradio\blocks.py", line 2220, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\gradio\blocks.py", line 1731, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\anyio\to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 2470, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 967, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\pc\Desktop\KAIM\intelligent-complaint-analysis-w6\.venv\Lib\site-packages\gradio\utils.py", line 940, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\pc\AppData\Local\Temp\ipykernel_3408\1497047482.py", line 10, in gradio_interface
#     result = answer_question_rag(query)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\pc\AppData\Local\Temp\ipykernel_3408\1497047482.py", line 5, in answer_question_rag
#     "answer": answer,
#               ^^^^^^
# NameError: name 'answer' is not defined
